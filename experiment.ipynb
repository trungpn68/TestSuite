# %%
import pandas as pd

df = pd.read_excel('AI Art Generator API.xlsx', sheet_name="Testcase API v3.1")

# %%
df = df[5:]

# %%
df.columns
# Out:
# Index([ 'Unnamed: 0',  'Unnamed: 1',  'Test case:',           228,
#           'TCs API ',  'Unnamed: 5',  'Unnamed: 6',  'Unnamed: 7',
#         'Unnamed: 8',  'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
df.columns = list(df.iloc[0, :])

# %%
df
# Out:
#     Test case ID                    Test case \n(Nội dung kiểm thử)  \
# 6          AAG01                                              TRUng
# 7          AAG02          Kiểm tra trường hợp để trống trường files
# 8          AAG03  Kiểm tra trường hợp upload ảnh đúng định dạng:...
# 9          AAG04  Kiểm tra trường hợp upload ảnh đúng định dạng jpg
# 10         AAG05  Kiểm tra trường hợp upload ảnh đúng định dạng ...
# ..           ...                                                ...
# 231       AAG226  Kiểm tra trường hợp Run script test all Styles...
# 232       AAG227  Kiểm tra trường hợp Run script test all Styles...
# 233       AAG228  Kiểm tra trường hợp input param hợp lệ và styl...
# 234       AAG229  Kiểm tra trường hợp input param hợp lệ và styl...
# 235       AAG230           Kiểm tra trường hợp import ảnh nặng 20MB
#
#     Pre-condition \n(Điều kiện)  \
# 6                           NaN
# 7                           NaN
# 8                           NaN
# ...
